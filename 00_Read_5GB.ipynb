# %%
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
from dask.distributed import LocalCluster, Client
from multiprocessing import Pool
import os
import time
from dask.distributed import progress

import json
import dask.bag as db

# %%
client = Client(n_workers=4, threads_per_worker=1, memory_limit='3GB')

# %% [markdown]
# ### Using 4 CPU cores parallelization

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:41585' processes=4 threads=4, memory=11.18 GiB>

# %%
chunk = 100000

# %% [markdown]
# ### Read json files into dataframe

# %%
print('')
mybag = db.read_text('*.json.gz').map(json.loads).repartition(chunk)

df = mybag.to_dataframe()
df.head()
# Out:
#            id         type                                              actor  \
# 0  2489368070    PushEvent  {'id': 9152315, 'login': 'davidjhulse', 'grava...
# 1  2489368072    PushEvent  {'id': 5581438, 'login': 'jmoon018', 'gravatar...
# 2  2489368089  CreateEvent  {'id': 6352424, 'login': 'christoferpeterson',...
# 3  2489368095    PushEvent  {'id': 66577, 'login': 'JakeWharton', 'gravata...
# 4  2489368104    PushEvent  {'id': 9221683, 'login': 'git4ruby', 'gravatar...
#
#                                                 repo  \
# 0  {'id': 28635890, 'name': 'davidjhulse/davesbin...
# 1  {'id': 26392647, 'name': 'jmoon018/rshell-unit...
# 2  {'id': 28677542, 'name': 'christoferpeterson/V...
# 3  {'id': 5152285, 'name': 'square/okhttp', 'url'...
# 4  {'id': 28520835, 'name': 'git4ruby/movie_revie...
#
#                                              payload  public  \
# 0  {'push_id': 536740396, 'size': 1, 'distinct_si...    True
# 1  {'push_id': 536740397, 'size': 1, 'distinct_si...    True
# 2  {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 3  {'push_id': 536740405, 'size': 8, 'distinct_si...    True
# 4  {'push_id': 536740413, 'size': 1, 'distinct_si...    True
#
#              created_at
# 0  2015-01-01T00:00:00Z
# 1  2015-01-01T00:00:00Z
# 2  2015-01-01T00:00:01Z
# 3  2015-01-01T00:00:01Z
# 4  2015-01-01T00:00:03Z

# %% [markdown]
# #### dataframe is not loaded into memory

# %%
df
# Out:
# Dask DataFrame Structure:
#                         id    type   actor    repo payload public created_at
# npartitions=100000
#                     object  object  object  object  object   bool     object
#                        ...     ...     ...     ...     ...    ...        ...
# ...                    ...     ...     ...     ...     ...    ...        ...
#                        ...     ...     ...     ...     ...    ...        ...
#                        ...     ...     ...     ...     ...    ...        ...
# Dask Name: to_dataframe, 200160 tasks

# %% [markdown]
# ### Unpacking actor,repo,payload tables into distinct dataframes

# %%
# extracting table actor
bag_actor = df['actor'].to_bag()
df_actor = bag_actor.to_dataframe()

df = df.drop('actor', axis=1)

# extracting table repo
bag_repo = df['repo'].to_bag()
df_repo = bag_repo.to_dataframe()

df = df.drop('repo', axis=1)


# extracting table payload
bag_payload = df['payload'].to_bag()
df_payload = bag_repo.to_dataframe()

df = df.drop('payload', axis=1)
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)

# %%
df_actor.head()
# Out:
#         id               login gravatar_id  \
# 0  9152315         davidjhulse
# 1  5581438            jmoon018
# 2  6352424  christoferpeterson
# 3    66577         JakeWharton
# 4  9221683            git4ruby
#
#                                                url  \
# 0         https://api.github.com/users/davidjhulse
# 1            https://api.github.com/users/jmoon018
# 2  https://api.github.com/users/christoferpeterson
# 3         https://api.github.com/users/JakeWharton
# 4            https://api.github.com/users/git4ruby
#
#                                          avatar_url
# 0  https://avatars.githubusercontent.com/u/9152315?
# 1  https://avatars.githubusercontent.com/u/5581438?
# 2  https://avatars.githubusercontent.com/u/6352424?
# 3    https://avatars.githubusercontent.com/u/66577?
# 4  https://avatars.githubusercontent.com/u/9221683?

# %%
df_repo.head()
# Out:
#          id                             name  \
# 0  28635890  davidjhulse/davesbingrewardsbot
# 1  26392647      jmoon018/rshell-unit-tester
# 2  28677542         christoferpeterson/Vadek
# 3   5152285                    square/okhttp
# 4  28520835           git4ruby/movie_review1
#
#                                                  url
# 0  https://api.github.com/repos/davidjhulse/daves...
# 1  https://api.github.com/repos/jmoon018/rshell-u...
# 2  https://api.github.com/repos/christoferpeterso...
# 3         https://api.github.com/repos/square/okhttp
# 4  https://api.github.com/repos/git4ruby/movie_re...

# %%
df_payload.head()
# Out:
#          id                             name  \
# 0  28635890  davidjhulse/davesbingrewardsbot
# 1  26392647      jmoon018/rshell-unit-tester
# 2  28677542         christoferpeterson/Vadek
# 3   5152285                    square/okhttp
# 4  28520835           git4ruby/movie_review1
#
#                                                  url
# 0  https://api.github.com/repos/davidjhulse/daves...
# 1  https://api.github.com/repos/jmoon018/rshell-u...
# 2  https://api.github.com/repos/christoferpeterso...
# 3         https://api.github.com/repos/square/okhttp
# 4  https://api.github.com/repos/git4ruby/movie_re...

# %%
df.head()
# Out:
#            id         type  public            created_at
# 0  2489368070    PushEvent    True  2015-01-01T00:00:00Z
# 1  2489368072    PushEvent    True  2015-01-01T00:00:00Z
# 2  2489368089  CreateEvent    True  2015-01-01T00:00:01Z
# 3  2489368095    PushEvent    True  2015-01-01T00:00:01Z
# 4  2489368104    PushEvent    True  2015-01-01T00:00:03Z
